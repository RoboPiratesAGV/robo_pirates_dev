# %%
# Authenticate gdrive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %env PROJECT_DIR=robo_pirates_dev
# %env GH_USERNAME="Iam-VM"
# %env GH_EMAIL="iamvm.dev@gmail.com"
# Out:
# env: PROJECT_DIR=robo_pirates_dev
# env: GH_USERNAME="Iam-VM"
# env: GH_EMAIL="iamvm.dev@gmail.com"

# %% [markdown]
# <details>
#   <summary>Pushing to github</summary>
#
#   ```shell
#     %%shell
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
#
#
# git add .
# git commit -m "<COMMIT MESSAGE>"
# git push origin master
# ```
# </details>

# %%
# %%shell
#
# mkdir -p /root/.ssh
# cp /content/drive/"MyDrive"/ed25519 /root/.ssh/ed25519
# eval `ssh-agent -s`
# ssh-add ~/.ssh/ed25519
# touch ~/.ssh/known_hosts
# ssh-keyscan -H github.com >> ~/.ssh/known_hosts
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
# pwd
#
#
#
#
# git add .
# git commit -m "<Enter Message>"
# git push origin master
# Out:
# Agent pid 364
# Identity added: /root/.ssh/ed25519 (vm@iam-vm)
# # github.com:22 SSH-2.0-babeld-91825f0b
# # github.com:22 SSH-2.0-babeld-91825f0b
# # github.com:22 SSH-2.0-babeld-91825f0b
# /content/drive/MyDrive/robo_pirates_dev
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@5feb5e18f471.(none)')
# Warning: Permanently added the RSA host key for IP address '140.82.114.4' to the list of known hosts.
# Everything up-to-date
