# %%
# Authenticate gdrive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %env PROJECT_DIR=robo_pirates_dev
# Out:
# env: PROJECT_DIR=robo_pirates_dev

# %% [markdown]
# <details>
#   <summary>Pushing to github</summary>
#
#   ```shell
#     %%shell
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
#
#
# git add .
# git commit -m "<COMMIT MESSAGE>"
# git push origin master
# ```
# </details>

# %%
# %%shell
#
# cp /contened25519 /root/.ssh/ed25519
# eval `ssh-agent -s`
# ssh-add ~/.ssh/ed25519
# touch ~/.ssh/known_hosts
# ssh-keyscan -H github.com >> ~/.ssh/known_hosts
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
# pwd
#
#
# git add .
# git commit -m "added github push spoiler"
# git push origin master
# Out:
# /content/drive/MyDrive/robo_pirates_dev
# [master 033a595] added github push spoiler
#  1 file changed, 1 insertion(+), 6 deletions(-)
#  rewrite pipeline.ipynb (100%)
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-26-75ca1c895047> in <module>()
# ----> 1 get_ipython().run_cell_magic('shell', '', ' \ncd /content/drive/"MyDrive"/\ncd "${PROJECT_DIR}"\npwd\n \n \ngit add .\ngit commit -m "added github push spoiler"\ngit push origin master')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# ...

# %%
# %%shell
#
# set -e
# set -x
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
#
# git config --global user.email "iamvm.dev@gmail.com"
# git config --global user.name "Iam-VM"
# Out:
# + cd /content/drive/MyDrive/
# + cd robo_pirates_dev
# + git config --global user.email iamvm.dev@gmail.com
# + git config --global user.name Iam-VM

# %%
# %%shell
#
# set -e
# set -x
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
#
# git config -l
# Out:
# + cd /content/drive/MyDrive/
# + cd robo_pirates_dev
# + git config -l
# user.email=iamvm.dev@gmail.com
# user.name=Iam-VM
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=git@github.com:RoboPiratesAGV/robo_pirates_dev.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.master.remote=origin
# branch.master.merge=refs/heads/master
