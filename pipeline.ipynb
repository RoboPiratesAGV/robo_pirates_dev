# %% [markdown]
# <details>
#   <summary>Mounting Google Drive [ Colab ]</summary>
#
# Copy paste this to a code cell and execute
#
# ```python
# # Authenticate gdrive
# from google.colab import drive
# drive.mount("/content/drive/")
# ```
#
# And run these commands in 2 seperate code cells
# ```shell
# cd /content/drive/"MyDrive"
# ```
#
# ```shell
# cd robo_pirates_dev
# ```
#
# </details>
