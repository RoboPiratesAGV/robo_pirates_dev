# %%
# Authenticate gdrive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %env PROJECT_DIR=robo_pirates_dev
# Out:
# env: PROJECT_DIR=robo_pirates_dev

# %% [markdown]
# <details>
#   <summary>Pushing to github</summary>
#
#   ```shell
#     %%shell
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
#
#
# git add .
# git commit -m "<COMMIT MESSAGE>"
# git push origin master
# ```
# </details>

# %%
# %%shell
#
# cp /content/drive/"MyDrive"/ed25519 /root/.ssh/ed25519
# eval `ssh-agent -s`
# ssh-add ~/.ssh/ed25519
# touch ~/.ssh/known_hosts
# ssh-keyscan -H github.com >> ~/.ssh/known_hosts
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
# pwd
#
#
# git add .
# git commit -m "removed t"
# git push origin master
# Out:
# Agent pid 636
# Identity added: /root/.ssh/ed25519 (vm@iam-vm)
# # github.com:22 SSH-2.0-babeld-e6b8e486
# # github.com:22 SSH-2.0-babeld-e6b8e486
# # github.com:22 SSH-2.0-babeld-e6b8e486
# /content/drive/MyDrive/robo_pirates_dev
# [master 806a941] added github push spoiler
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite pipeline.ipynb (82%)
# Warning: Permanently added the RSA host key for IP address '140.82.112.4' to the list of known hosts.
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 3.44 KiB | 703.00 KiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To github.com:RoboPiratesAGV/robo_pirates_dev.git
#    24a0cbf..806a941  master -> master
