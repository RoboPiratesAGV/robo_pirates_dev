# %%
# Authenticate gdrive
from google.colab import drive
drive.mount("/content/drive/")

# %% [markdown]
# ##RUN AFTER ADDING YOUR GITHUB EMAIL, USERNAME AND COMMIT MESSAGE

# %%
# %%shell
#
# PROJECT_DIR=robo_pirates_dev
# GH_USERNAME="Iam-VM"
# GH_EMAIL="iamvm.dev@gmail.com"
#
# COMMIT_MESSAGE="created seperate commit script file"
#
# mkdir -p /root/.ssh
# cp /content/drive/"MyDrive"/ed25519 /root/.ssh/ed25519
# eval `ssh-agent -s`
# ssh-add ~/.ssh/ed25519
# touch ~/.ssh/known_hosts
# ssh-keyscan -H github.com >> ~/.ssh/known_hosts
#
# cd /content/drive/"MyDrive"/
# cd "${PROJECT_DIR}"
# pwd
#
# git config --global user.email "${GH_EMAIL}"
# git config --global user.name "${GH_USERNAME}"
#
#  ## for committing specific files replace the '.' with file name.
# git add .
# git commit -m "${COMMIT_MESSAGE}"
# git push origin master
